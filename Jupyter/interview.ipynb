# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-1.8.0-openjdk-amd64"
os.environ["SPARK_HOME"] = "/home/hadoop/work/spark-3.2.0-bin-hadoop2.7"
os.environ["PYSPARK_PYTHON"] = "/usr/bin/python3.8"
os.environ["PYSPARK_DRIVER_PYTHON"] = "/usr/bin/python3.8"

# %%
#!pip install -q findspark
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
        .master("local")\
        .appName("Word Count RDD")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()
# Out:
# 21/12/07 14:51:07 WARN util.Utils: Your hostname, hadoop-Lenovo-G50-80 resolves to a loopback address: 127.0.1.1; using 192.168.1.8 instead (on interface wlp3s0)
# 21/12/07 14:51:07 WARN util.Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 21/12/07 14:51:08 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import  split,explode,col,count

sc = spark.sparkContext
df = spark.read.text("word_cnt.txt") # return DataFrame object
print(type(df))
df.show(5, truncate=False)

dfwords = df.withColumn('words', split(col('value'), ' ')) \
    .withColumn('word', explode(col('words'))) \
    .drop('value', 'words') \
    .groupby('word') \
    .agg(count('word').alias('count')) \
    .orderBy('count', ascending=False) \
    .show(10, truncate=False)

print("Word Count DataFrame Spark SQL")
sqllines = df.createOrReplaceTempView('lines')

spark.sql("""select word, count(word) count from
 (select explode(split(value,' '))  word from lines) words group by word order by count desc""").show(10)
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# +---------------------------------------------------------------------------------------------------------+
# |value                                                                                                    |
# +---------------------------------------------------------------------------------------------------------+
# |it was the best of times it was the worst of times it was the age of wisdom it was the age of foolishness|
# +---------------------------------------------------------------------------------------------------------+
#
# +-----------+-----+
# |word       |count|
# +-----------+-----+
# |the        |4    |
# |of         |4    |
# |was        |4    |
# |it         |4    |
# |times      |2    |
# |age        |2    |
# |worst      |1    |
# |wisdom     |1    |
# |foolishness|1    |
# |best       |1    |
# +-----------+-----+
#
# Word Count DataFrame Spark SQL
# +-----------+-----+
# |       word|count|
# +-----------+-----+
# |        the|    4|
# |         of|    4|
# |        was|    4|
# |         it|    4|
# |      times|    2|
# |        age|    2|
# |      worst|    1|
# |     wisdom|    1|
# |foolishness|    1|
# |       best|    1|
# +-----------+-----+

# %%
from pyspark.sql.functions import split, col, explode, count

from pyspark import SparkConf, SparkContext

conf = SparkConf().setAppName(" Word Count RDD ")
sc = SparkContext.getOrCreate(conf=conf)

text = sc.textFile('word_cnt.txt') # return RDD object
print(type(text))
print(text.collect())
# Out:
# <class 'pyspark.rdd.RDD'>
# ['it was the best of times it was the worst of times it was the age of wisdom it was the age of foolishness']

# %%
rdd2 = text.flatMap(lambda x: x.split(' '))
print(rdd2.collect())
# Out:
# ['it', 'was', 'the', 'best', 'of', 'times', 'it', 'was', 'the', 'worst', 'of', 'times', 'it', 'was', 'the', 'age', 'of', 'wisdom', 'it', 'was', 'the', 'age', 'of', 'foolishness']

# %%
rdd3 = rdd2.map(lambda x: (x, 1))
print(rdd3.collect())
# Out:
# [('it', 1), ('was', 1), ('the', 1), ('best', 1), ('of', 1), ('times', 1), ('it', 1), ('was', 1), ('the', 1), ('worst', 1), ('of', 1), ('times', 1), ('it', 1), ('was', 1), ('the', 1), ('age', 1), ('of', 1), ('wisdom', 1), ('it', 1), ('was', 1), ('the', 1), ('age', 1), ('of', 1), ('foolishness', 1)]

# %%
rdd3 = rdd2.map(lambda x: (x, 1))
print(rdd3.collect())

rdd4 = rdd3.reduceByKey(lambda x, y: x + y)
print(rdd4.collect())

# all operation in 1 line
print("Word Count in 1 line ")

counts = text.flatMap(lambda line: line.split(" ")) \
    .map(lambda word: (word, 1)) \
    .reduceByKey(lambda x, y: x + y)

print(counts.collect())
# Out:
# [('it', 1), ('was', 1), ('the', 1), ('best', 1), ('of', 1), ('times', 1), ('it', 1), ('was', 1), ('the', 1), ('worst', 1), ('of', 1), ('times', 1), ('it', 1), ('was', 1), ('the', 1), ('age', 1), ('of', 1), ('wisdom', 1), ('it', 1), ('was', 1), ('the', 1), ('age', 1), ('of', 1), ('foolishness', 1)]
# [('it', 4), ('was', 4), ('the', 4), ('best', 1), ('of', 4), ('times', 2), ('worst', 1), ('age', 2), ('wisdom', 1), ('foolishness', 1)]
# Word Count in 1 line
# [('it', 4), ('was', 4), ('the', 4), ('best', 1), ('of', 4), ('times', 2), ('worst', 1), ('age', 2), ('wisdom', 1), ('foolishness', 1)]
# 21/12/07 15:23:32 WARN hdfs.DFSClient: DFSOutputStream ResponseProcessor exception  for block BP-830212574-127.0.1.1-1633618224355:blk_1073742469_1654
# java.net.SocketTimeoutException: 65000 millis timeout while waiting for channel to be ready for read. ch : java.nio.channels.SocketChannel[connected local=/127.0.0.1:57316 remote=/127.0.0.1:50010]
# 	at org.apache.hadoop.net.SocketIOWithTimeout.doIO(SocketIOWithTimeout.java:164)
# 	at org.apache.hadoop.net.SocketInputStream.read(SocketInputStream.java:161)
# 	at org.apache.hadoop.net.SocketInputStream.read(SocketInputStream.java:131)
# 	at org.apache.hadoop.net.SocketInputStream.read(SocketInputStream.java:118)
# 	at java.io.FilterInputStream.read(FilterInputStream.java:83)
# 	at java.io.FilterInputStream.read(FilterInputStream.java:83)
# 	at org.apache.hadoop.hdfs.protocolPB.PBHelper.vintPrefixed(PBHelper.java:2292)
# 	at org.apache.hadoop.hdfs.protocol.datatransfer.PipelineAck.readFields(PipelineAck.java:244)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer$ResponseProcessor.run(DFSOutputStream.java:847)
# 21/12/07 15:23:34 WARN spark.HeartbeatReceiver: Removing executor driver with no recent heartbeats: 328792 ms exceeds timeout 120000 ms
# 21/12/07 15:23:34 WARN spark.SparkContext: Killing executors is not supported by current scheduler.
# 21/12/07 15:23:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:23:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:24:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:24:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:24:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:24:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:24:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:24:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:25:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:25:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:25:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:25:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:25:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:25:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:26:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:26:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:26:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:26:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:26:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:26:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:27:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:27:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:27:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:27:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:27:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:27:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:28:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:28:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:28:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:28:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:28:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:28:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:29:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:29:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:29:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:29:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:29:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:29:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:30:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:30:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:30:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:30:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:30:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:30:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:31:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:31:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:31:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:31:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:31:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:31:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:32:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:32:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:32:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:32:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:32:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:32:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:33:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:33:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:33:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:33:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:33:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:33:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:34:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:34:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:34:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:34:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:34:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:34:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:35:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:35:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:35:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:35:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:35:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:35:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:36:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:36:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:36:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:36:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:36:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:36:50 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:37:00 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:37:10 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:37:20 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:37:30 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 15:37:40 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# ...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:33:39 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:33:49 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:33:59 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:34:09 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:34:19 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:34:29 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:34:39 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:34:49 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:34:59 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:35:09 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:35:19 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:35:29 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:35:39 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:35:49 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:35:59 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:36:09 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:36:19 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:36:29 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:36:39 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:36:49 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:36:59 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:37:09 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:37:19 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:37:29 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:37:39 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:37:49 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:37:59 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:38:09 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
# 21/12/07 18:38:19 ERROR scheduler.AsyncEventQueue: Listener EventLoggingListener threw an exception
# java.io.IOException: All datanodes DatanodeInfoWithStorage[127.0.0.1:50010,DS-4c838208-1b36-41fb-b0e1-00fb9eea48df,DISK] are bad. Aborting...
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.setupPipelineForAppendOrRecovery(DFSOutputStream.java:1224)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.processDatanodeError(DFSOutputStream.java:990)
# 	at org.apache.hadoop.hdfs.DFSOutputStream$DataStreamer.run(DFSOutputStream.java:507)
